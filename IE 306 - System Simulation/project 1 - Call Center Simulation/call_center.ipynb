# %%
import simpy
import numpy as np

#RANDOM_SEEDS = np.random.uniform(0, 1000, 10)
#RANDOM_SEEDS = list(map(int, RANDOM_SEEDS))
RANDOM_SEEDS = [0, 194, 482, 241, 832, 997, 352, 153, 56, 569]
TOTAL_CUSTOMER = 0   # We are gonna change it to 5000 after applying 10 different seed.

INTERARRIVAL_RATE = 6
MACHINE_WAIT_RATE = 5
SHIFT_TIME = 8*60
SIM_OVER = False

N_MEAN = np.log(12/(np.sqrt(1 + ((6**2)/(12**2)))))
N_STD = np.sqrt(np.log(1 + ((6**2)/(12**2))))

num_customers_unsatisfied = 0
num_waiting_customer = [0, 0]
system_end_time = 0
answering_times = [] #Duration of the conversation between the customer and the anwering system. (Info collecting time)
service_times = [[],[]] #Duration of the conversation between the customer and the operator (Service time)
queue_w_times = [[],[]] #Time spent by a customer while it waits for the operator (Queue waiting time Wq)
customer_total_system_t = []

answering_utils = []
operators_utils = [[], []]
ave_total_waiting_times = []
max_total_w_system_time_ratios = []
ave_people_w_OP0s = []
ave_people_w_OP1s = []
num_people_unsatisfieds = []

# %%
class Customer(object):
    
    def __init__(self, name, env, arrival_t, operator):
        self.env = env
        self.name = name
        self.operator = operator
        self.arrival_t = arrival_t
        self.departure_t = float('inf')
        self.action = self.env.process(self.call())
        

    def call(self):
        operator_no = int(np.random.random() > 0.3)
        correct_operator = np.random.random() > 0.1
        global system_end_time, num_customers_unsatisfied, num_waiting_customer
        if correct_operator:
            current_operator = self.operator[operator_no]
            with current_operator.resource.request() as request:
                num_waiting_customer[operator_no] += 1
                self.entering_queue_t = self.env.now
                patience = self.env.timeout(10)
                yield request | patience
                waiting_t_queue = self.env.now - self.entering_queue_t
                if(waiting_t_queue == 0):
                    num_waiting_customer[operator_no] -= 1
            
                queue_w_times[operator_no].append(waiting_t_queue)
                if request.triggered:
                    yield self.env.process(current_operator.serve())
                    self.departure_t = self.env.now
                else:
                    num_customers_unsatisfied += 1
                
        else:
            queue_w_times[operator_no].append(0) 
            num_customers_unsatisfied += 1
            
        customer_total_system_t.append(self.env.now - self.arrival_t)
            
        system_end_time = self.env.now
        if(len(queue_w_times[0]) + len(queue_w_times[1]) == TOTAL_CUSTOMER):
            SIM_OVER = True

# %%
class Operator(object):

    def __init__(self, env, name, res):
        self.resource = res
        self.env = env
        self.name = name
        self.breaks_to_take = 0
        self.breaks_from_prev = 0
        self.number_of_breaks = np.random.poisson(8)
        self.env.process(self.schedule_break())
        self.env.process(self.shift_change())
       
    
    def take_break(self):
        flag = False
        if(SIM_OVER):
            return
        with self.resource.request() as request:
            yield request
            if(SIM_OVER):
                return
            if(self.breaks_from_prev > 0 ):
                self.breaks_from_prev -= 1
                flag = True
            else:
                if len(self.resource.queue) == self.breaks_to_take - 1:
                    self.breaks_to_take -= 1
                    remaining_shift_time = (8 * 60) - (self.env.now % (8 * 60))
                    if(remaining_shift_time < 3):
                        yield self.env.timeout(remaining_shift_time)
                    else:
                        yield self.env.timeout(3)
                    flag = True

        if not flag:
            yield self.env.process(self.take_break())
    
    
    def serve(self):
        global service_times
        if self.name == 0:
            service_time = np.random.lognormal(N_MEAN,N_STD)
        else:
            service_time = np.random.uniform(1,7)
        service_times[self.name].append(service_time)
        yield self.env.timeout(service_time)
        
        
    def schedule_break(self):
        break_times = sorted(np.random.uniform(0, 8*60, self.number_of_breaks))
        for break_time in break_times:
            if(SIM_OVER):
                return
            duration = break_time - (self.env.now % (8 * 60))
            duration = duration if duration > 0 else 0
            yield self.env.timeout(duration)
            self.breaks_to_take += 1
            self.env.process(self.take_break())            

            
    def shift_change(self):
        while not SIM_OVER:
            yield self.env.timeout(8*60)
            if(SIM_OVER):
                return
            self.breaks_from_prev = self.breaks_to_take
            self.breaks_to_take = 0
            self.number_of_breaks = np.random.poisson(8)
            self.env.process(self.schedule_break())

# %%
class AnsweringSystem(object):
    
    def __init__(self, env, counter, operators, machine):
        self.env = env
        self.counter = counter
        self.operators = operators
        self.machine = machine
        self.action = self.env.process(self.run())
        
        
    def run(self):
        with self.machine.request() as request:
            yield request
            arrival_t = self.env.now
            duration = np.random.exponential(MACHINE_WAIT_RATE)
            answering_times.append(duration)   # We are gonna use it to find utilization of answering system
            yield self.env.timeout(duration)
            Customer('Cust %s' %(self.counter), self.env, arrival_t, self.operators)

# %%
def customer_generator(env, operators, machine):
    global SIM_OVER
    counter = 0
    while(counter < TOTAL_CUSTOMER):
        yield env.timeout(np.random.exponential(INTERARRIVAL_RATE))
        if machine.count < 100:
            counter += 1
            AnsweringSystem(env, counter, operators, machine)
    SIM_OVER = True

# %%
def reset_global_variables():
    global num_customers_unsatisfied, num_waiting_customer
    global system_end_time,service_times,queue_w_times,customer_total_system_t
    
    num_customers_unsatisfied = 0
    num_waiting_customer = [0, 0]
    system_end_time = 0
    answering_times = [] 
    service_times = [[],[]] 
    queue_w_times = [[],[]] 
    customer_total_system_t = []
    num_people_unsatisfied = 0
    
    
def simulate(seed):
    np.random.seed(seed)
    env = simpy.Environment()
    operator_queues = [simpy.Resource(env, capacity = 1), simpy.Resource(env, capacity = 1)]
    operators = [Operator(env, 0, operator_queues[0]), Operator(env, 1, operator_queues[1])]
    machine = simpy.Resource(env, capacity = 100)
    env.process(customer_generator(env, operators, machine))
    env.run()

    
def collect_data():
    global num_customers_unsatisfied, num_waiting_customer
    global system_end_time,service_times,queue_w_times,customer_total_system_t
    
    #1 Utilization of the answering system
    total_answering_time = sum(answering_times)
    answering_utils.append((total_answering_time / system_end_time)/ 100 ) 

    #2 Utilization of the operators  
    OP0_util = sum(service_times[0]) / system_end_time
    OP1_util = sum(service_times[1]) / system_end_time 
    operators_utils[0].append(OP0_util)
    operators_utils[1].append(OP1_util)

    #3 Average Total Waiting Time
    ave_total_waiting_time = (sum(queue_w_times[0]) + sum(queue_w_times[1])) / TOTAL_CUSTOMER
    ave_total_waiting_times.append(ave_total_waiting_time)

    #4 Maximum Total Waiting Time to Total System Time Ratio
    max_total_w_system_time_ratio = (sum(queue_w_times[0]) + sum(queue_w_times[1]))/sum(customer_total_system_t)
    max_total_w_system_time_ratios.append(max_total_w_system_time_ratio)

    #5 Average number of people waiting to be served by each operator
    ave_people_w_OP0 = sum(queue_w_times[0]) / system_end_time
    ave_people_w_OP1 = sum(queue_w_times[1]) / system_end_time
    ave_people_w_OP0s.append(ave_people_w_OP0)
    ave_people_w_OP1s.append(ave_people_w_OP1)

    #6 Average number of customers leaving the system unsatisfied either due to incorrect routing or due to long waiting times.
    num_people_unsatisfied = num_customers_unsatisfied
    num_people_unsatisfieds.append(num_people_unsatisfied)

def print_statistics():
    for i in range(0,10):
        print(f"###########")
        print(f"Simulation {i+1} with {TOTAL_CUSTOMER} customers.")
        print(f"###########")
        print(f"Utilization of the answering system: {answering_utils[i]}")
        print(f"Utilization of the operator 0: {operators_utils[0][i]}")
        print(f"Utilization of the operator 1: {operators_utils[1][i]}")
        print(f"Average Total Waiting Time: {ave_total_waiting_times[i]}")
        print(f"Maximum Total Waiting Time to Total System Time Ratio: {max_total_w_system_time_ratios[i]}")
        print(f"Average number of people waiting to be served by the operator 0: {ave_people_w_OP0s[i]}")
        print(f"Average number of people waiting to be served by the operator 1: {ave_people_w_OP1s[i]}")
        print(f"Number of customers leaving the system unsatisfied: {num_people_unsatisfieds[i]}")
    print(f"###########")
    print(f"General results of simulations with {TOTAL_CUSTOMER} customers.")
    print(f"###########")
    print(f"Means".center(15,"-"))
    print(f"Utilization of the answering system: {np.mean(answering_utils)}")
    print(f"Utilization of the operator 0: {np.mean(operators_utils[0])}")
    print(f"Utilization of the operator 1: {np.mean(operators_utils[1])}")
    print(f"Average Total Waiting Time: {np.mean(ave_total_waiting_times)}")
    print(f"Maximum Total Waiting Time to Total System Time Ratio: {np.mean(max_total_w_system_time_ratios)}")
    print(f"Average number of people waiting to be served by the operator 0: {np.mean(ave_people_w_OP0s)}")
    print(f"Average number of people waiting to be served by the operator 1: {np.mean(ave_people_w_OP1s)}")
    print(f"Variances".center(15,"-"))
    print(f"Utilization of the answering system: {np.var(answering_utils)}")
    print(f"Utilization of the operator 0: {np.var(operators_utils[0])}")
    print(f"Utilization of the operator 1: {np.var(operators_utils[1])}")
    print(f"Average Total Waiting Time: {np.var(ave_total_waiting_times)}")
    print(f"Maximum Total Waiting Time to Total System Time Ratio: {np.var(max_total_w_system_time_ratios)}")
    print(f"Average number of people waiting to be served by the operator 0: {np.var(ave_people_w_OP0s)}")
    print(f"Average number of people waiting to be served by the operator 1: {np.var(ave_people_w_OP1s)}")
    print(f"Others".center(15,"-"))
    print(f"Average number of customers leaving the system unsatisfied (for 1000 customers): {sum(num_people_unsatisfieds)/len(num_people_unsatisfieds)}")

# %%
answering_utils = []
operators_utils = [[], []]
ave_total_waiting_times = []
max_total_w_system_time_ratios = []
ave_people_w_OP0s = []
ave_people_w_OP1s = []
num_people_unsatisfieds = []

TOTAL_CUSTOMER = 1000
for seed in RANDOM_SEEDS:
    reset_global_variables()
    simulate(seed)
    collect_data()
print_statistics()
# Out:
# ###########
# Simulation 1 with 1000 customers.
# ###########
# Utilization of the answering system: 0.008033934698879452
# Utilization of the operator 0: 0.4770058440650503
# Utilization of the operator 1: 0.3898222629010887
# Average Total Waiting Time: 1.8439275281934189
# Maximum Total Waiting Time to Total System Time Ratio: 0.15242145050602074
# Average number of people waiting to be served by the operator 0: 0.14502247233692525
# Average number of people waiting to be served by the operator 1: 0.15533623254363113
# Number of customers leaving the system unsatisfied: 153
# ###########
# Simulation 2 with 1000 customers.
# ###########
# Utilization of the answering system: 0.01624086973354822
# Utilization of the operator 0: 0.4467955570341096
# Utilization of the operator 1: 0.4196633541650185
# Average Total Waiting Time: 1.7901401499336975
# Maximum Total Waiting Time to Total System Time Ratio: 0.14804426682848051
# Average number of people waiting to be served by the operator 0: 0.1375493831550975
# Average number of people waiting to be served by the operator 1: 0.1551156925343666
# Number of customers leaving the system unsatisfied: 142
# ###########
# Simulation 3 with 1000 customers.
# ###########
# Utilization of the answering system: 0.024798478314344105
# Utilization of the operator 0: 0.45327053489181907
# Utilization of the operator 1: 0.41040384904908067
# Average Total Waiting Time: 1.705026461659195
# Maximum Total Waiting Time to Total System Time Ratio: 0.14456622106158482
# Average number of people waiting to be served by the operator 0: 0.14020198086951177
# Average number of people waiting to be served by the operator 1: 0.14450903443004542
# Number of customers leaving the system unsatisfied: 146
# ###########
# Simulation 4 with 1000 customers.
# ###########
# Utilization of the answering system: 0.03264922889956245
# Utilization of the operator 0: 0.45236167332879706
# Utilization of the operator 1: 0.386137132889956
# Average Total Waiting Time: 1.846284968362957
# Maximum Total Waiting Time to Total System Time Ratio: 0.1494990566971673
# Average number of people waiting to be served by the operator 0: 0.15715230191272905
# Average number of people waiting to be served by the operator 1: 0.14165529529058224
# Number of customers leaving the system unsatisfied: 148
# ###########
# Simulation 5 with 1000 customers.
# ###########
# Utilization of the answering system: 0.042420548372992695
# Utilization of the operator 0: 0.4180735911981812
# Utilization of the operator 1: 0.4047667029418984
# Average Total Waiting Time: 1.7886989427203936
# Maximum Total Waiting Time to Total System Time Ratio: 0.1527698119360265
# Average number of people waiting to be served by the operator 0: 0.11737170879836403
# Average number of people waiting to be served by the operator 1: 0.1836787574563201
# Number of customers leaving the system unsatisfied: 171
# ###########
# Simulation 6 with 1000 customers.
# ###########
# Utilization of the answering system: 0.04941789479796853
# Utilization of the operator 0: 0.4501263328319842
# Utilization of the operator 1: 0.3935006489237403
# Average Total Waiting Time: 2.00365617234925
# Maximum Total Waiting Time to Total System Time Ratio: 0.1615157975116306
# Average number of people waiting to be served by the operator 0: 0.16861161277258896
# Average number of people waiting to be served by the operator 1: 0.15695157827807263
# Number of customers leaving the system unsatisfied: 166
# ###########
# Simulation 7 with 1000 customers.
# ###########
# Utilization of the answering system: 0.0559686907619226
# Utilization of the operator 0: 0.4607761670166294
# Utilization of the operator 1: 0.3793760305316826
# Average Total Waiting Time: 1.6930748750188487
# Maximum Total Waiting Time to Total System Time Ratio: 0.140315231263044
# Average number of people waiting to be served by the operator 0: 0.13939438617652544
# Average number of people waiting to be served by the operator 1: 0.12780706481922005
# Number of customers leaving the system unsatisfied: 162
# ###########
# Simulation 8 with 1000 customers.
# ###########
# Utilization of the answering system: 0.06885237985156908
# Utilization of the operator 0: 0.43194547224638136
# Utilization of the operator 1: 0.41693638380926856
# Average Total Waiting Time: 1.9732661641931561
# Maximum Total Waiting Time to Total System Time Ratio: 0.1644831437047054
# Average number of people waiting to be served by the operator 0: 0.13769387974405428
# Average number of people waiting to be served by the operator 1: 0.1978184967929449
# Number of customers leaving the system unsatisfied: 171
# ###########
# Simulation 9 with 1000 customers.
# ###########
# Utilization of the answering system: 0.07449853275970508
# Utilization of the operator 0: 0.4454918417097471
# Utilization of the operator 1: 0.417322224299758
# Average Total Waiting Time: 1.9914513661339095
# Maximum Total Waiting Time to Total System Time Ratio: 0.1628159823357831
# Average number of people waiting to be served by the operator 0: 0.16417691465498332
# Average number of people waiting to be served by the operator 1: 0.16211624792596582
# Number of customers leaving the system unsatisfied: 157
# ###########
# Simulation 10 with 1000 customers.
# ###########
# Utilization of the answering system: 0.0865733841706447
# Utilization of the operator 0: 0.44815761917521896
# Utilization of the operator 1: 0.42178725347092927
# Average Total Waiting Time: 1.614101050910807
# Maximum Total Waiting Time to Total System Time Ratio: 0.1389519084050433
# Average number of people waiting to be served by the operator 0: 0.11608793473046575
# Average number of people waiting to be served by the operator 1: 0.16114030242808242
# Number of customers leaving the system unsatisfied: 148
# ###########
# General results of simulations with 1000 customers.
# ###########
# -----Means-----
# Utilization of the answering system: 0.0459453942361137
# Utilization of the operator 0: 0.4484004633497918
# Utilization of the operator 1: 0.4039715842982421
# Average Total Waiting Time: 1.8249627679475633
# Maximum Total Waiting Time to Total System Time Ratio: 0.15153828702494862
# Average number of people waiting to be served by the operator 0: 0.14232625751512454
# Average number of people waiting to be served by the operator 1: 0.15861287024992313
# ---Variances---
# Utilization of the answering system: 0.0006059212153235727
# Utilization of the operator 0: 0.00022153939380396858
# Utilization of the operator 1: 0.00021848142736512395
# Average Total Waiting Time: 0.01612274591268425
# Maximum Total Waiting Time to Total System Time Ratio: 7.459533214952121e-05
# Average number of people waiting to be served by the operator 0: 0.00027640172427875146
# Average number of people waiting to be served by the operator 1: 0.0003645243101849177
# -----Others----
# Average number of customers leaving the system unsatisfied (for 1000 customers): 156.4

# %%
answering_utils = []
operators_utils = [[], []]
ave_total_waiting_times = []
max_total_w_system_time_ratios = []
ave_people_w_OP0s = []
ave_people_w_OP1s = []
num_people_unsatisfieds = []
    
TOTAL_CUSTOMER = 5000
for seed in RANDOM_SEEDS:
    reset_global_variables()
    simulate(seed)
    collect_data()   
print_statistics()
# Out:
# ###########
# Simulation 1 with 5000 customers.
# ###########
# Utilization of the answering system: 0.02546129775996787
# Utilization of the operator 0: 0.4603565122440308
# Utilization of the operator 1: 0.41410401592443813
# Average Total Waiting Time: 1.7981712713816145
# Maximum Total Waiting Time to Total System Time Ratio: 0.15094589214111315
# Average number of people waiting to be served by the operator 0: 0.13770176338476992
# Average number of people waiting to be served by the operator 1: 0.166859832424807
# Number of customers leaving the system unsatisfied: 792
# ###########
# Simulation 2 with 5000 customers.
# ###########
# Utilization of the answering system: 0.03367904854828251
# Utilization of the operator 0: 0.45891675068121196
# Utilization of the operator 1: 0.4195596114491836
# Average Total Waiting Time: 1.8901394963420046
# Maximum Total Waiting Time to Total System Time Ratio: 0.15720238768651806
# Average number of people waiting to be served by the operator 0: 0.14932632532821333
# Average number of people waiting to be served by the operator 1: 0.1696042102284554
# Number of customers leaving the system unsatisfied: 790
# ###########
# Simulation 3 with 5000 customers.
# ###########
# Utilization of the answering system: 0.041638792767928375
# Utilization of the operator 0: 0.4543094857341848
# Utilization of the operator 1: 0.41509526062114577
# Average Total Waiting Time: 1.7808504005258954
# Maximum Total Waiting Time to Total System Time Ratio: 0.1496114486817079
# Average number of people waiting to be served by the operator 0: 0.13283855406055908
# Average number of people waiting to be served by the operator 1: 0.16512938343445335
# Number of customers leaving the system unsatisfied: 758
# ###########
# Simulation 4 with 5000 customers.
# ###########
# Utilization of the answering system: 0.05003177652586597
# Utilization of the operator 0: 0.4479589603224846
# Utilization of the operator 1: 0.4156085525601708
# Average Total Waiting Time: 1.7964104351346588
# Maximum Total Waiting Time to Total System Time Ratio: 0.14890001641342757
# Average number of people waiting to be served by the operator 0: 0.13501344393407058
# Average number of people waiting to be served by the operator 1: 0.16478250656346735
# Number of customers leaving the system unsatisfied: 786
# ###########
# Simulation 5 with 5000 customers.
# ###########
# Utilization of the answering system: 0.05880766065848863
# Utilization of the operator 0: 0.438796982076412
# Utilization of the operator 1: 0.41550931451716416
# Average Total Waiting Time: 1.85714451847068
# Maximum Total Waiting Time to Total System Time Ratio: 0.15521621134195399
# Average number of people waiting to be served by the operator 0: 0.14169106749530072
# Average number of people waiting to be served by the operator 1: 0.17032773910076215
# Number of customers leaving the system unsatisfied: 802
# ###########
# Simulation 6 with 5000 customers.
# ###########
# Utilization of the answering system: 0.0676791019639612
# Utilization of the operator 0: 0.4529465259313572
# Utilization of the operator 1: 0.419564330985372
# Average Total Waiting Time: 1.9714130935273935
# Maximum Total Waiting Time to Total System Time Ratio: 0.16263005179778933
# Average number of people waiting to be served by the operator 0: 0.1556580846571146
# Average number of people waiting to be served by the operator 1: 0.17792727012812973
# Number of customers leaving the system unsatisfied: 782
# ###########
# Simulation 7 with 5000 customers.
# ###########
# Utilization of the answering system: 0.07386709517345572
# Utilization of the operator 0: 0.45476152615730386
# Utilization of the operator 1: 0.403128107639452
# Average Total Waiting Time: 1.7524515080016048
# Maximum Total Waiting Time to Total System Time Ratio: 0.14558434089916453
# Average number of people waiting to be served by the operator 0: 0.13299623070132002
# Average number of people waiting to be served by the operator 1: 0.1543499998802792
# Number of customers leaving the system unsatisfied: 760
# ###########
# Simulation 8 with 5000 customers.
# ###########
# Utilization of the answering system: 0.08325921839011649
# Utilization of the operator 0: 0.4508760541264013
# Utilization of the operator 1: 0.4063583739719773
# Average Total Waiting Time: 1.7679315340908135
# Maximum Total Waiting Time to Total System Time Ratio: 0.14877996175298785
# Average number of people waiting to be served by the operator 0: 0.13735848666343728
# Average number of people waiting to be served by the operator 1: 0.15694609524335063
# Number of customers leaving the system unsatisfied: 836
# ###########
# Simulation 9 with 5000 customers.
# ###########
# Utilization of the answering system: 0.09122960011373114
# Utilization of the operator 0: 0.4462047781828401
# Utilization of the operator 1: 0.40373993164094407
# Average Total Waiting Time: 1.7414146822147119
# Maximum Total Waiting Time to Total System Time Ratio: 0.14744461391755798
# Average number of people waiting to be served by the operator 0: 0.14122086601091813
# Average number of people waiting to be served by the operator 1: 0.14782252131889598
# Number of customers leaving the system unsatisfied: 832
# ###########
# Simulation 10 with 5000 customers.
# ###########
# Utilization of the answering system: 0.10199961076447861
# Utilization of the operator 0: 0.44620907053439884
# Utilization of the operator 1: 0.4194777847969266
# Average Total Waiting Time: 1.878996286644935
# Maximum Total Waiting Time to Total System Time Ratio: 0.15710316826254941
# Average number of people waiting to be served by the operator 0: 0.1484244841365301
# Average number of people waiting to be served by the operator 1: 0.1712366937784058
# Number of customers leaving the system unsatisfied: 796
# ###########
# General results of simulations with 5000 customers.
# ###########
# -----Means-----
# Utilization of the answering system: 0.06276532026662765
# Utilization of the operator 0: 0.45113366459906246
# Utilization of the operator 1: 0.4132145284106774
# Average Total Waiting Time: 1.823492322633431
# Maximum Total Waiting Time to Total System Time Ratio: 0.152341809289477
# Average number of people waiting to be served by the operator 0: 0.14122293063722338
# Average number of people waiting to be served by the operator 1: 0.16449862521010067
# ---Variances---
# Utilization of the answering system: 0.0005778676962606713
# Utilization of the operator 0: 3.830554272923893e-05
# Utilization of the operator 1: 3.736449102610951e-05
# Average Total Waiting Time: 0.004859901594261774
# Maximum Total Waiting Time to Total System Time Ratio: 2.639879340585575e-05
# Average number of people waiting to be served by the operator 0: 5.299868398575174e-05
# Average number of people waiting to be served by the operator 1: 7.299571295408031e-05
# -----Others----
# Average number of customers leaving the system unsatisfied (for 1000 customers): 793.4
